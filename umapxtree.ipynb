# %%
import plotly.express as px
# from umap import UMAP
# from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import numpy as np
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split


# Load Kaggle MNIST dataset (adjust path as needed)
df = pd.read_csv('train.csv')  # Path to Kaggle's train.csv
y = df['label'].values  # Labels (0-9)
x = df.drop('label', axis=1).values  # 784 features (28x28 pixels)

# # Subsample for faster computation
# n_samples = 42000
# X = X[:n_samples]
# y = y[:n_samples]

# Define parameter ranges
# n_epochs_list = [100, 200, 300, 400, 500, 600]
# n_components_list = [2, 3, 5, 10, 20, 30, 40, 50]

# # Store results
# results = []

# # Iterate over combinations of n_epochs and n_components
# for n_epochs in n_epochs_list:
#     for n_components in n_components_list:
#         # Apply UMAP
#         umap = UMAP(n_components=n_components, n_epochs=n_epochs, random_state=42, verbose=True)
#         X_reduced = umap.fit_transform(X)
        
#         # Split reduced data
#         X_train, X_test, y_train, y_test = train_test_split(X_reduced, y, test_size=0.2, random_state=42)
        
#         # Train Decision Tree
#         clf = DecisionTreeClassifier(random_state=42)
#         clf.fit(X_train, y_train)
        
#         # Compute accuracy
#         y_pred = clf.predict(X_test)
#         accuracy = accuracy_score(y_test, y_pred)
        
#         # Store result
#         results.append({
#             'n_epochs': n_epochs,
#             'n_components': n_components,
#             'accuracy': accuracy
#         })

# # Create DataFrame for Plotly
# df_results = pd.DataFrame(results)
# # Create 3D scatter plot
# fig = px.scatter_3d(
#     df_results,
#     x='n_epochs',
#     y='n_components',
#     z='accuracy',
#     color='accuracy',
#     size_max=10,
#     title='Impact of UMAP Epochs and Dimensions on Decision Tree Accuracy',
#     labels={
#         'n_epochs': 'Number of Epochs',
#         'n_components': 'Reduced Dimensions',
#         'accuracy': 'Accuracy'
#     },
#     width=1000,
#     height=800,
#     color_continuous_scale='Viridis'
# )

# # Update layout for better readability
# fig.update_layout(
#     scene=dict(
#         xaxis_title='Number of Epochs',
#         yaxis_title='Reduced Dimensions',
#         zaxis_title='Accuracy'
#     ),
#     margin=dict(l=0, r=0, b=0, t=50)
# )

# # Show the plot
# fig.show()

# %%
df_results = pd.read_csv('umap_results.csv')
  # Load precomputed results
# fig = px.scatter_3d(
#     df_results,
#     x='n_epochs',
#     y='n_components',
#     z='accuracy',
#     color='accuracy',
#     size_max=10,
#     title='Impact of UMAP Epochs and Dimensions on Decision Tree Accuracy',
#     labels={
#         'n_epochs': 'Number of Epochs',
#         'n_components': 'Reduced Dimensions',
#         'accuracy': 'Accuracy'
#     },
#     width=1000,
#     height=800,
#     color_continuous_scale='Viridis'
# )

# # Update layout for better readability
# fig.update_layout(
#     scene=dict(
#         xaxis_title='Number of Epochs',
#         yaxis_title='Reduced Dimensions',
#         zaxis_title='Accuracy'
#     ),
#     margin=dict(l=0, r=0, b=0, t=50)
# )

# # Show the plot
# fig.show()

# accuracy_matrix =  df_results.pivot_table(
#     index='n_epochs',
#     columns='n_components',
#     values='accuracy',
#     aggfunc=np.mean
# ).fillna(0)

# acc_min = np.nanmin(accuracy_matrix)
# acc_max = np.nanmax(accuracy_matrix)
# accuracy_scaled = (accuracy_matrix - acc_min) / (acc_max - acc_min)
# fig2=go.Figure(data=go.Heatmap(
#     z=accuracy_scaled.values,
#     x=accuracy_matrix.columns,
#     y=accuracy_matrix.index,
#     colorscale='Viridis',
#     colorbar=dict(title='Accuracy'),
#     zmin=0, zmax=1
# ))
# fig2.update_layout(
#     title='Heatmap of UMAP Epochs and Dimensions vs Accuracy',
#     xaxis_title='Reduced Dimensions',
#     yaxis_title='Number of Epochs',
#     width=800,
#     height=600
# )
# # Show the heatmap
# fig2.show()

# %%
from sklearn.neural_network import MLPClassifier
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

mlc_model= MLPClassifier(
    hidden_layer_sizes=(100, 50),
    activation='relu',
    solver='adam',
    max_iter=1000,
    random_state=42,
    verbose=True
)
mlc_model.fit(x_train, y_train)
y_pred = mlc_model.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"MLP Classifier Accuracy: {accuracy:.4f}")
# Out:
# Iteration 1, loss = 4.18584784
# Iteration 2, loss = 0.88531462
# Iteration 3, loss = 0.59332509
# Iteration 4, loss = 0.44544190
# Iteration 5, loss = 0.36293398
# Iteration 6, loss = 0.30263615
# Iteration 7, loss = 0.24835339
# Iteration 8, loss = 0.21545717
# Iteration 9, loss = 0.19590151
# Iteration 10, loss = 0.18816014
# Iteration 11, loss = 0.16313901
# Iteration 12, loss = 0.14549959
# Iteration 13, loss = 0.12833831
# Iteration 14, loss = 0.11744973
# Iteration 15, loss = 0.12050247
# Iteration 16, loss = 0.11763438
# Iteration 17, loss = 0.10045501
# Iteration 18, loss = 0.10177000
# Iteration 19, loss = 0.09884473
# Iteration 20, loss = 0.08948986
# Iteration 21, loss = 0.08389065
# Iteration 22, loss = 0.08102255
# Iteration 23, loss = 0.07243409
# Iteration 24, loss = 0.09232837
# Iteration 25, loss = 0.07741570
# Iteration 26, loss = 0.07192373
# Iteration 27, loss = 0.08632907
# Iteration 28, loss = 0.07370752
# Iteration 29, loss = 0.07094129
# ...
